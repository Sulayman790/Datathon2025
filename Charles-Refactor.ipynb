# %%
# !pip install langdetect spacy beautifulsoup4 lxml instructor pydantic
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: langdetect in /opt/conda/lib/python3.11/site-packages (1.0.9)
# Requirement already satisfied: spacy in /opt/conda/lib/python3.11/site-packages (3.8.7)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (4.14.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.11/site-packages (5.4.0)
# Requirement already satisfied: instructor in /opt/conda/lib/python3.11/site-packages (1.12.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.11/site-packages (2.12.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from langdetect) (1.17.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /opt/conda/lib/python3.11/site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /opt/conda/lib/python3.11/site-packages (from instructor) (3.13.0)
# Requirement already satisfied: diskcache>=5.6.3 in /opt/conda/lib/python3.11/site-packages (from instructor) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /opt/conda/lib/python3.11/site-packages (from instructor) (0.17.0)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /opt/conda/lib/python3.11/site-packages (from instructor) (0.10.0)
# Requirement already satisfied: openai<2.0.0,>=1.70.0 in /opt/conda/lib/python3.11/site-packages (from instructor) (1.109.1)
# Requirement already satisfied: pre-commit>=4.3.0 in /opt/conda/lib/python3.11/site-packages (from instructor) (4.3.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /opt/conda/lib/python3.11/site-packages (from instructor) (2.41.4)
# Requirement already satisfied: rich<15.0.0,>=13.7.0 in /opt/conda/lib/python3.11/site-packages (from instructor) (14.2.0)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /opt/conda/lib/python3.11/site-packages (from instructor) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.70.0->instructor) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.70.0->instructor) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.70.0->instructor) (0.28.1)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.70.0->instructor) (1.3.1)
# Requirement already satisfied: cfgv>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pre-commit>=4.3.0->instructor) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from pre-commit>=4.3.0->instructor) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /opt/conda/lib/python3.11/site-packages (from pre-commit>=4.3.0->instructor) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from pre-commit>=4.3.0->instructor) (6.0.3)
# Requirement already satisfied: virtualenv>=20.10.0 in /opt/conda/lib/python3.11/site-packages (from pre-commit>=4.3.0->instructor) (20.35.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich<15.0.0,>=13.7.0->instructor) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich<15.0.0,>=13.7.0->instructor) (2.19.2)
# Requirement already satisfied: cloudpickle>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from srsly<3.0.0,>=2.4.3->spacy) (3.1.1)
# Requirement already satisfied: ujson>=1.35 in /opt/conda/lib/python3.11/site-packages (from srsly<3.0.0,>=2.4.3->spacy) (5.11.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.4.1)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.70.0->instructor) (0.16.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor) (0.1.2)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/conda/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /opt/conda/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/conda/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor) (4.5.0)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 130.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # Setup, configuration, file & HTML utilities

# %%
# %% [markdown]
# ## 1) Setup, configuration, file & HTML utilities
# - Imports and environment configuration (AWS region, model IDs, paths, size limits)
# - AWS clients (Translate + Bedrock)
# - Stopwords, regexes, language constants
# - File discovery & deduplication helpers
# - HTML parsing and main-text extraction helpers

# %%
import os, re, json, html, string, unicodedata
from pathlib import Path
from datetime import datetime, timezone, date
import boto3
import pandas as pd
from bs4 import BeautifulSoup
from dateutil.parser import parse as parse_date
from langdetect import detect, detect_langs, DetectorFactory
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text as sk_text

DetectorFactory.seed = 42

AWS_REGION=os.getenv("AWS_REGION","us-west-2")
MODEL_TRANSLATE_FALLBACK_1=os.getenv("BEDROCK_TRANSLATE_PRIMARY","amazon.nova-micro-v1:0")
MODEL_TRANSLATE_FALLBACK_2=os.getenv("BEDROCK_TRANSLATE_SECONDARY","anthropic.claude-3-7-sonnet-20250219-v1:0")
MODEL_EXTRACT=os.getenv("BEDROCK_EXTRACT_MODEL","amazon.nova-premier-v1:0")
MODEL_EXTRACT_DOC=os.getenv("BEDROCK_EXTRACT_DOC_MODEL","amazon.nova-premier-v1:0:1000k")

INPUT_DIRS=json.loads(os.getenv("INPUT_DIRS","[\"./directives\"]"))
ALLOWED_EXT=set([x.lower().strip() for x in json.loads(os.getenv("ALLOWED_EXT","[\".html\",\".xml\"]"))])
RECURSIVE=os.getenv("RECURSIVE","true").strip().lower() in {"1","true","yes"}
OUT_DIR=os.getenv("OUT_DIR","out")
MAX_DOC_CHARS=int(os.getenv("MAX_DOC_CHARS","180000"))
MAX_CHUNK_CHARS=int(os.getenv("MAX_CHUNK_CHARS","18000"))

translate=boto3.client("translate",region_name=AWS_REGION)
bedrock=boto3.client("bedrock-runtime",region_name=AWS_REGION)

EXTRA_STOPWORDS={"section","sections","article","articles","annex","annexe","appendix","appendice","subtitle","title","chapter","chapitre","directive","regulation","regulations","law","act","union","paragraph","subparagraph","recital","dispositif","premier","1er","amended","shall","must","may","including","include","pursuant","accordance","specified","provide","provided","applicable","applicability","applying","applicant","applicants","applying","subject","subjects","thereof","hereof","therein","herein","thereby","hereby","whereas","hereunder","thereunder","among","between","within","without","preamble","scope","purpose","purposes","general","specific"}
STOPWORDS_EN=set(sk_text.ENGLISH_STOP_WORDS)|EXTRA_STOPWORDS

STOPWORDS_JA={"第","条","項","号","章","節","款","目次","附則","総則","抄","同","前","又は","及び","並びに","その他","こと","もの","ため","者","うえ","上","下","について","に関する","に係る","する","される","した","して","すると","され","なる","ない","これ","それ","当該","各","同条","政府","国","内閣","大臣","本部","本部長","本法","本章","本条","次項","前項","人工知能","人工知能関連技術","技術","研究開発","活用","推進","計画","基本","基本計画","施策","規定","規範","方針","必要","措置","整備","確保","促進","国際","協力","教育","人材","情報","データ","等","など"}
STRUCTURAL_LABEL_JA={"総則","附則","目次","人工知能基本計画","人工知能戦略本部"}

PARLIAMENTARY=re.compile(r"^\s*(having regard|after transmission|after consulting|in accordance with|whereas|pursuant to|considering|vu(?:\s+la|(?:x|es)?)?)\b.*$",re.IGNORECASE|re.MULTILINE)
RECITALS=re.compile(r"\b(whereas|considérant(?:\s+que)?|vu(?:\s+la|(?:x|es)?)?)\b.*?(?=(^|\n)\s*(article|art\.?|dispositif|chapitre|titre)\s*[^\n]*\b(1|premier|1er)\b|\bannex|annexe|appendix|appendice|schedule\b)",re.IGNORECASE|re.DOTALL)
TAIL=re.compile(r"(done at\s+[A-Za-z]+\s+\d{1,2}\s+[A-Za-z]+\s+\d{4}.*$|for the european parliament.*$|for the council.*$)",re.IGNORECASE|re.DOTALL)
DATE_RX=re.compile(r"(\b\d{1,2}\s+(jan|feb|mar|apr|may|jun|jul|aug|sep|sept|oct|nov|dec)[a-z]*\s+\d{4}\b|\b\d{4}-\d{1,2}-\d{1,2}\b|\b\d{1,2}[./]\d{1,2}[./]\d{2,4}\b)",re.IGNORECASE)
CJK_DATE_RX=re.compile(r"(\d{4})年(\d{1,2})月(\d{1,2})日")
JP_ERA=[("令和",2019),("平成",1989),("昭和",1926),("大正",1912),("明治",1868)]

def _resolve_input_dir():
    for d in INPUT_DIRS:
        p=Path(d)
        if p.exists(): return p
    p=Path("./directives"); p.mkdir(parents=True,exist_ok=True); return p

def _canon_name(p: Path):
    stem=p.stem
    stem=re.sub(r"(?i)(^|[-_\s])(checkpoint|copy|copie|copiar)$","",stem).strip()
    stem=re.sub(r"(?i)[-_]checkpoint","",stem)
    stem=re.sub(r"\s*\(\d+\)$","",stem)
    stem=re.sub(r"\s+"," ",stem)
    return (stem.lower(), p.suffix.lower())

def _is_checkpoint(p: Path):
    name=p.name.lower()
    return ("-checkpoint" in name or name.endswith("_checkpoint.html") or "checkpoint.html" in name or name.endswith(".ipynb") or p.parent.name.lower()==".ipynb_checkpoints" or ".ipynb_checkpoints" in str(p.parent).lower())

def _list_files(root,recursive=False):
    def ok(p):
        n=p.name
        if _is_checkpoint(p): return False
        if p.parent.name == ".ipynb_checkpoints": return False
        return p.is_file() and p.suffix.lower() in ALLOWED_EXT and not (n.startswith(".") or n.startswith("._") or n.endswith("~"))
    it=(root.rglob("*") if recursive else root.iterdir())
    cand=[p for p in it if ok(p)]
    grouped={}
    for p in cand:
        key=_canon_name(p); best=grouped.get(key)
        if best is None: grouped[key]=p
        else:
            if _is_checkpoint(best) and not _is_checkpoint(p): grouped[key]=p
            elif _is_checkpoint(best)==_is_checkpoint(p):
                if p.stat().st_mtime>best.stat().st_mtime: grouped[key]=p
    files=sorted(grouped.values(),key=lambda x:x.name.lower())
    print(f"[INPUT] {len(files)} files in {root} (recursive={recursive})")
    for p in files: print(" -",p.name)
    return files

def _read(path): return Path(path).read_text(encoding="utf-8",errors="ignore")

def _extract_main_container(soup):
    for sel in ["#innerDocument","main#contentsLaw","#docHtml","article","#content","body"]:
        el=soup.select_one(sel)
        if el and len(el.get_text(strip=True))>200: return el
    return soup

def _html_to_text(raw):
    try: soup=BeautifulSoup(raw,"lxml")
    except Exception: soup=BeautifulSoup(raw,"html.parser")
    main=_extract_main_container(soup)
    for tag in main(["script","style","nav","header","footer","noscript","aside","form"]):
        try: tag.extract()
        except Exception: pass
    for br in main.find_all(["br","hr"]): br.replace_with("\n")
    for li in main.find_all("li"):
        txt=li.get_text(" ",strip=True); li.string=("\n- "+txt+"\n") if txt else "\n"
    for th in main.find_all(["h1","h2","h3","h4","h5","h6","strong","b"]):
        t=th.get_text(" ",strip=True); th.string=("\n"+t+"\n") if t else "\n"
    text=html.unescape(main.get_text("\n",strip=True))
    text=re.sub(r"\n{3,}","\n\n",text)
    return text,soup

def _extract_main_title(soup, fallback):
    try: t=soup.title.get_text(strip=True) if soup and soup.title else ""
    except Exception: t=""
    try: h=soup.find(["h1","h2"]); h1=h.get_text(" ",strip=True) if h else ""
    except Exception: h1=""
    return next((x for x in [h1,t,fallback] if x),fallback)

# %% [markdown]
# # Language detection/translation, date parsing, NLP extraction & aggregation

# %%
# %% [markdown]
# ## 2) Language detection/translation, date parsing, NLP extraction & aggregation
# - Detects English and translates (Amazon Translate → Bedrock fallbacks), chunking long texts
# - Prunes recitals/tails/TOC to keep operative content
# - Parses dates (regex, CJK, Japanese eras)
# - Extracts per-chunk and per-document fields via Bedrock LLMs
# - Builds TF-IDF keywords and normalizes/aggregates all fields into one row

# %%
def _has_cjk(s): return bool(re.search(r"[\u3400-\u4dbf\u4e00-\u9fff\u3040-\u30ff]",s or ""))

def _lang_probs(text):
    try: return detect_langs(text)
    except Exception:
        try: return [type("LP",(object,),{"lang":detect(text),"prob":1.0})()]
        except Exception: return []

def _english_confidence(text):
    t=(text or "").strip()
    if not t: return 1.0
    sample=t[:8000]
    letters=[ch for ch in sample if ch.isalpha()]
    ascii_letters=[ch for ch in letters if ("A"<=ch<="Z") or ("a"<=ch<="z")]
    ascii_ratio=(len(ascii_letters)/max(1,len(letters))) if letters else 0.0
    tokens=[w.strip(string.punctuation).lower() for w in re.split(r"\s+",sample) if w]
    stop_hits=sum(1 for tok in tokens if tok in sk_text.ENGLISH_STOP_WORDS)
    stop_ratio=stop_hits/max(1,len(tokens))
    ld_prob=0.0
    for lp in _lang_probs(sample):
        if getattr(lp,"lang","")=="en": ld_prob=max(ld_prob,float(getattr(lp,"prob",0.0)))
    score=0.75*ld_prob+0.25*(0.6*ascii_ratio+0.4*stop_ratio)
    return max(0.0,min(1.0,score))

def _is_english(text):
    if not text or len(text.strip())==0: return True
    if _has_cjk(text):
        try: return detect(text)=="en"
        except Exception: return False
    if len(text)<160:
        try: return detect(text)=="en"
        except Exception: return False
    return _english_confidence(text)>=0.55

def _translate_piece_bedrock(piece,model_id,system_prompt=None):
    body={"max_tokens":4000,"temperature":0.0}
    if "anthropic" in model_id:
        body={"anthropic_version":"bedrock-2023-05-31","max_tokens":4000,"temperature":0.0,"messages":[{"role":"user","content":[{"type":"text","text":"Translate this to precise legal English. Keep headings, numbering, dates, entities verbatim. No commentary.\n\n"+piece}]}]}
    else:
        prompt="Translate the following text into precise legal English. Preserve headings, numbering, and dates. No commentary.\n\n"+piece
        body={"inputText":prompt,"textGenerationConfig":{"maxTokenCount":4000,"temperature":0.0}}
    try:
        resp=bedrock.invoke_model(modelId=model_id,body=json.dumps(body))
        data=json.loads(resp["body"].read())
        if "anthropic" in model_id: return data.get("content",[{}])[0].get("text","")
        return data.get("outputText","")
    except Exception:
        return ""

def _chunk_for_translate(t,limit=4200):
    out=[]; i=0; n=len(t)
    seps=["\n\n","。\n","。\n\n","；","；\n","；\n\n","，","。\n—\n","\n- "]
    while i<n:
        j=min(i+limit,n)
        k=-1
        for sep in seps:
            ks=t.rfind(sep,i,j)
            if ks>k: k=ks+len(sep)
        if k<i+200: k=j
        piece=t[i:k].strip(); i=k
        if piece: out.append(piece)
    return out

def _force_english(text):
    if not text: return text
    if _is_english(text): return text
    chunks=_chunk_for_translate(text,limit=4000)
    out=[]
    for piece in chunks:
        ok=False
        try:
            r=translate.translate_text(Text=piece,SourceLanguageCode="auto",TargetLanguageCode="en")
            cand=r.get("TranslatedText","") or ""
            if cand.strip() and _is_english(cand): out.append(cand); ok=True
        except Exception: pass
        if not ok:
            cand=_translate_piece_bedrock(piece,MODEL_TRANSLATE_FALLBACK_1)
            if cand.strip() and _is_english(cand): out.append(cand); ok=True
        if not ok:
            cand=_translate_piece_bedrock(piece,MODEL_TRANSLATE_FALLBACK_2)
            if cand.strip():
                out.append(cand if _is_english(cand) else _translate_piece_bedrock(cand,MODEL_TRANSLATE_FALLBACK_1))
    final="\n".join([c for c in out if c]).strip()
    return final if final else text

def _translate(text):
    t=(text or "").strip()
    if not t: return t
    if _is_english(t): return t
    out=_force_english(t)
    if not _is_english(out): out=_force_english(out)
    return out

def _prune_operative(text_en):
    x=PARLIAMENTARY.sub("",text_en)
    x=RECITALS.sub("",x)
    x=TAIL.sub("",x)
    x=re.sub(r"\bTable of Contents\b.*?(?=(^|\n)\s*Article\s+(1|premier|1er)\b)", "", x, flags=re.IGNORECASE|re.DOTALL)
    return x.strip()

def _chunk_iter(text,limit=MAX_CHUNK_CHARS):
    i=0; n=len(text)
    seps=["\n\n","\n- ","; ",". "]
    while i<n:
        j=min(i+limit,n)
        k=-1
        for sep in seps:
            ks=text.rfind(sep,i,j)
            if ks>k: k=ks+len(sep)
        if k<i+200: k=j
        piece=text[i:k].strip(); i=k
        if piece: yield piece

def _to_ymd(s):
    try: return parse_date(s,fuzzy=True,dayfirst=False).date().isoformat()
    except Exception: return ""

def _parse_cjk_date(s):
    m=CJK_DATE_RX.search(s)
    if not m: return ""
    y=int(m.group(1)); mth=int(m.group(2)); d=int(m.group(3))
    try: return date(y,mth,d).isoformat()
    except Exception: return ""

def _parse_jp_era(s):
    m=re.search(r"(令和|平成|昭和|大正|明治)\s*([元\d]+)\s*年\s*([0-9]{1,2})\s*月\s*([0-9]{1,2})\s*日",s)
    if not m: return ""
    era=m.group(1); year=m.group(2); month=int(m.group(3)); day=int(m.group(4))
    base=dict(JP_ERA)[era]; y=1 if year=="元" else int(year)
    try: return date(base+y-1,month,day).isoformat()
    except Exception: return ""

def _doc_date(raw_text,soup,fname):
    cands=[]
    try: cands.extend(el.get_text(" ",strip=True) for el in soup.select("#lawTitleNo,#lawTitle,.oj-hd-date,.oj-doc-ti,.date,.document-date,.pubdate,.issued,.enacted,.approved,#lawTitleNo"))
    except Exception: pass
    head=" ".join(cands)
    jp=_parse_jp_era(head) or _parse_jp_era(raw_text[:120000])
    if jp: return jp
    cjk=_parse_cjk_date(head) or _parse_cjk_date(raw_text[:120000])
    if cjk: return cjk
    for m in DATE_RX.findall(head):
        d=_to_ymd(m[0])
        if d: return d
    for m in DATE_RX.findall(raw_text[:120000]):
        d=_to_ymd(m[0])
        if d: return d
    m=re.search(r"(\d{4})[-_](\d{1,2})[-_](\d{1,2})",Path(fname).name)
    if m:
        try: return datetime(int(m.group(1)),int(m.group(2)),int(m.group(3))).date().isoformat()
        except Exception: pass
    m=re.search(r"\b(19|20)\d{2}\b",Path(fname).name)
    if m:
        try: return datetime(int(m.group(0)),6,30).date().isoformat()
        except Exception: pass
    try:
        ts=Path(fname).stat().st_mtime
        return datetime.fromtimestamp(ts,tz=timezone.utc).date().isoformat()
    except Exception:
        return datetime.now(timezone.utc).date().isoformat()

def _ensure_ascii_lower(s: str):
    s=(s or "").strip()
    s=unicodedata.normalize("NFKD", s).encode("ascii","ignore").decode("ascii")
    s=re.sub(r"[^A-Za-z0-9%/_\-\s]", "", s)
    s=re.sub(r"\s+"," ", s).strip().lower()
    return s

def _kw_from_text(text_en, max_k=40):
    try:
        vec=TfidfVectorizer(stop_words=list(STOPWORDS_EN),ngram_range=(1,2),min_df=1,token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z%/_-]+\b")
        X=vec.fit_transform([text_en]); scores=X.toarray()[0]; terms=vec.get_feature_names_out()
        pairs=sorted(zip(terms,scores),key=lambda x:-x[1])
        bad={"article","articles","annex","section","chapter","law","act","directive","regulation","regulations","union","paragraph","recital","subparagraph","subtitle","title"}
        out=[]
        for t,_ in pairs:
            tl=_ensure_ascii_lower(t)
            if tl in bad or tl in STOPWORDS_EN: continue
            if re.fullmatch(r"\d+(\.\d+)?",tl): continue
            if len(tl)<=2: continue
            if tl not in out: out.append(tl)
            if len(out)>=max_k: break
        return out
    except Exception:
        return []

def _llm_extract_chunk(chunk_en):
    prompt=("Return a strict JSON object with keys exactly:\n"
            "jurisdiction (string), sector (array of strings), activity (array of strings), regulatory_theme (array of strings), impact_type (array of strings), regulator (array of strings), company_country (array of strings), effective_date (YYYY-MM-DD or \"\").\n"
            "Use only this text, be concise, lowercase labels except jurisdictions/regulators/countries (title case), deduplicate.\n\nTEXT:\n"+chunk_en[:MAX_CHUNK_CHARS])
    body={"messages":[{"role":"user","content":[{"type":"text","text":prompt}]}],"max_tokens":3000,"temperature":0.0}
    try:
        resp=bedrock.invoke_model(modelId=MODEL_EXTRACT,body=json.dumps(body))
        parsed=json.loads(resp["body"].read())
        text_out=parsed.get("content",[{}])[0].get("text","{}")
        data=json.loads(text_out)
        def normlist(v):
            if isinstance(v,list): return [str(x).strip() for x in v if str(x).strip()]
            if isinstance(v,str) and v.strip(): return [v.strip()]
            return []
        return {
            "jurisdiction":str(data.get("jurisdiction","")).strip(),
            "sector":normlist(data.get("sector",[])),
            "activity":normlist(data.get("activity",[])),
            "regulatory_theme":normlist(data.get("regulatory_theme",[])),
            "impact_type":normlist(data.get("impact_type",[])),
            "regulator":normlist(data.get("regulator",[])),
            "company_country":normlist(data.get("company_country",[])),
            "effective_date":str(data.get("effective_date","")).strip()
        }
    except Exception:
        return {"jurisdiction":"","sector":[],"activity":[],"regulatory_theme":[],"impact_type":[],"regulator":[],"company_country":[],"effective_date":""}

def _llm_extract_doc(title, text_en):
    prompt=("From the following title and document, infer a single JSON object with keys exactly:\n"
            "jurisdiction (string), sector (array), activity (array), regulatory_theme (array), impact_type (array), regulator (array), company_country (array), default_effective_date (YYYY-MM-DD or \"\").\n\n"
            "TITLE:\n"+(title or "")+"\n\nDOCUMENT:\n"+(text_en[:MAX_DOC_CHARS] or ""))
    body={"messages":[{"role":"user","content":[{"type":"text","text":prompt}]}],"max_tokens":6000,"temperature":0.0}
    try:
        resp=bedrock.invoke_model(modelId=MODEL_EXTRACT_DOC,body=json.dumps(body))
        parsed=json.loads(resp["body"].read())
        text_out=parsed.get("content",[{}])[0].get("text","{}")
        data=json.loads(text_out)
        def normlist(v):
            if isinstance(v,list): return [str(x).strip() for x in v if str(x).strip()]
            if isinstance(v,str) and v.strip(): return [v.strip()]
            return []
        return {
            "jurisdiction":str(data.get("jurisdiction","")).strip(),
            "sector":normlist(data.get("sector",[])),
            "activity":normlist(data.get("activity",[])),
            "regulatory_theme":normlist(data.get("regulatory_theme",[])),
            "impact_type":normlist(data.get("impact_type",[])),
            "regulator":normlist(data.get("regulator",[])),
            "company_country":normlist(data.get("company_country",[])),
            "default_effective_date":str(data.get("default_effective_date","")).strip()
        }
    except Exception:
        return {"jurisdiction":"","sector":[],"activity":[],"regulatory_theme":[],"impact_type":[],"regulator":[],"company_country":[],"default_effective_date":""}

def _to_title(s):
    s=_ensure_ascii_lower(s)
    return " ".join([w.capitalize() for w in s.split()])

def _norm_titlecase(items): return sorted(list(dict.fromkeys([_to_title(x) for x in items if x.strip()])))
def _norm_lower(items): return sorted(list(dict.fromkeys([_ensure_ascii_lower(x) for x in items if _ensure_ascii_lower(x)])))

def _aggregate_fields(doc_backfill, chunk_fields_list, corpus_text_en, doc_date_guess):
    juris=doc_backfill.get("jurisdiction","").strip() or ""
    sectors=set(doc_backfill.get("sector",[]))
    activities=set(doc_backfill.get("activity",[]))
    themes=set(doc_backfill.get("regulatory_theme",[]))
    impacts=set(doc_backfill.get("impact_type",[]))
    regulators=set(doc_backfill.get("regulator",[]))
    countries=set(doc_backfill.get("company_country",[]))
    eff=doc_backfill.get("default_effective_date","").strip() or ""

    for cf in chunk_fields_list:
        if not juris and cf.get("jurisdiction",""): juris=cf["jurisdiction"]
        sectors.update(cf.get("sector",[]))
        activities.update(cf.get("activity",[]))
        themes.update(cf.get("regulatory_theme",[]))
        impacts.update(cf.get("impact_type",[]))
        regulators.update(cf.get("regulator",[]))
        countries.update(cf.get("company_country",[]))
        if not eff and cf.get("effective_date",""): eff=cf["effective_date"]

    if not eff:
        head=corpus_text_en[:8000]
        m=DATE_RX.search(head)
        if m: eff=_to_ymd(m[0]) or eff
        if not eff: eff=doc_date_guess

    juris = _to_title(juris) if juris else "Global"
    regulators=_norm_titlecase(regulators)
    countries=_norm_titlecase(countries) if countries else ([juris] if juris!="Global" else ["Global"])
    sectors=_norm_lower(sectors) or ["general"]
    activities=_norm_lower(activities) or ["general"]
    themes=_norm_lower(themes) or ["general"]
    impacts=_norm_lower(impacts) or ["obligation"]
    eff = eff or ""

    kws=_kw_from_text(corpus_text_en, max_k=50)

    return {
        "jurisdiction": juris,
        "sector": sectors,
        "activity": activities,
        "regulatory_theme": themes,
        "impact_type": impacts,
        "effective_date": eff,
        "regulator": regulators or ["General Regulator"],
        "keywords": kws,
        "company_country": countries
    }

# %% [markdown]
# # Serialization, saving & pipeline orchestration

# %%
# %% [markdown]
# ## 3) Serialization, saving & pipeline orchestration
# - Serializes arrays as JSON strings for CSV columns
# - Saves one CSV per input and a combined "ALL" CSV
# - `process_file`: end-to-end for one document (parse → translate → prune → extract → aggregate)
# - `process_all_documents`: loops over files and returns a DataFrame
# - Main guard to run the batch when executed as a script

# %%
def _serialize_row(row):
    def J(x): return json.dumps(x, ensure_ascii=False)
    return {
        "jurisdiction": row["jurisdiction"],
        "sector": J(sorted(row["sector"])),
        "activity": J(sorted(row["activity"])),
        "regulatory_theme": J(sorted(row["regulatory_theme"])),
        "impact_type": J(sorted(row["impact_type"])),
        "effective_date": row["effective_date"],
        "regulator": J(sorted(row["regulator"])),
        "keywords": J(row["keywords"]),
        "company_country": J(sorted(row["company_country"]))
    }

def _save_per_input(row,input_path):
    Path(OUT_DIR).mkdir(parents=True,exist_ok=True)
    stem=input_path.stem
    csv_path=f"{OUT_DIR}/{stem}.csv"
    df=pd.DataFrame([_serialize_row(row)],columns=["jurisdiction","sector","activity","regulatory_theme","impact_type","effective_date","regulator","keywords","company_country"])
    df.to_csv(csv_path,index=False)
    print(f"[SAVE] {csv_path}")

def _save_all(rows):
    Path(OUT_DIR).mkdir(parents=True,exist_ok=True)
    csv_path=f"{OUT_DIR}/Regulatory_Extraction_ALL.csv"
    df=pd.DataFrame([_serialize_row(r) for r in rows],columns=["jurisdiction","sector","activity","regulatory_theme","impact_type","effective_date","regulator","keywords","company_country"])
    df.to_csv(csv_path,index=False)
    print(f"[SAVE] {csv_path}")

def process_file(path: Path):
    raw=_read(path)
    raw_txt,soup=_html_to_text(raw)
    title=_extract_main_title(soup, path.stem)
    en=_translate(raw_txt)
    if not _is_english(en): en=_force_english(en)
    operative=_prune_operative(en)
    doc_date_guess=_doc_date(raw_txt,soup,str(path))
    back=_llm_extract_doc(title, operative)

    chunk_fields=[]
    for chunk in _chunk_iter(operative, limit=MAX_CHUNK_CHARS):
        c_en=_translate(chunk)
        if not _is_english(c_en): c_en=_force_english(c_en)
        f=_llm_extract_chunk(c_en)
        chunk_fields.append(f)

    row=_aggregate_fields(back, chunk_fields, operative, back.get("default_effective_date") or doc_date_guess)
    return row

def process_all_documents():
    root=_resolve_input_dir()
    files=_list_files(root,recursive=RECURSIVE)
    if not files:
        print("[WARN] no inputs"); return pd.DataFrame()
    all_rows=[]
    for f in files:
        row=process_file(f)
        _save_per_input(row,f)
        all_rows.append(row)
        print(f"[FILE] {Path(f).name}: 1 row")
    _save_all(all_rows)
    df=pd.DataFrame([_serialize_row(r) for r in all_rows],columns=["jurisdiction","sector","activity","regulatory_theme","impact_type","effective_date","regulator","keywords","company_country"])
    print(f"[TOTAL] {len(df)} rows")
    return df

if __name__=="__main__":
    df=process_all_documents()
    print(df.head() if not df.empty else "No results")
# Out:
# [INPUT] 1 files in directives (recursive=True)
#  - 2.H.R.1 - One Big Beautiful Bill Act.xml
# [SAVE] out/2.H.R.1 - One Big Beautiful Bill Act.csv
# [FILE] 2.H.R.1 - One Big Beautiful Bill Act.xml: 1 row
# [SAVE] out/Regulatory_Extraction_ALL.csv
# [TOTAL] 1 rows
#   jurisdiction       sector     activity regulatory_theme     impact_type  \
# 0       Global  ["general"]  ["general"]      ["general"]  ["obligation"]
#
#   effective_date              regulator  \
# 0     2025-07-04  ["General Regulator"]
#
#                                             keywords company_country
# 0  ["year", "subsection", "sec", "inserting", "st...      ["Global"]

# %% [markdown]
# # Translation with English recognition

# %%
import json
from pathlib import Path
import boto3
from botocore.config import Config
from bs4 import BeautifulSoup
from langdetect import detect, DetectorFactory
from concurrent.futures import ThreadPoolExecutor

AWS_REGION = "us-west-2"
OUT_DIR = "out/translate"
MAX_CHUNK_CHARS = 4000

DetectorFactory.seed = 42

bedrock = boto3.client("bedrock-runtime", region_name=AWS_REGION, config=Config(read_timeout=60, retries={"max_attempts": 3}))

PROFILE_IDS = {
    "anthropic_haiku_4_5": "global.anthropic.claude-haiku-4-5-20251001-v1:0",
    "anthropic_sonnet_4_5": "global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    "anthropic_sonnet_4": "global.anthropic.claude-sonnet-4-20250514-v1:0"
}

def log(msg):
    print(f"[LOG] {msg}")

def get_files():
    p = Path("./directives")
    if not p.exists():
        log("directives folder not found")
        return []
    files = [f for f in p.iterdir() if f.is_file() and f.suffix.lower() in {".html", ".xml"}]
    log(f"Detected {len(files)} eligible files in directives folder")
    return files

def html_to_text(raw):
    soup = BeautifulSoup(raw, "html.parser")
    for tag in soup(["script", "style", "nav", "header", "footer"]):
        tag.extract()
    text = soup.get_text(" ", strip=True)
    log(f"Extracted {len(text)} characters of text from HTML")
    return text

def chunk_text(text, limit=MAX_CHUNK_CHARS):
    chunks, i = [], 0
    while i < len(text):
        end = min(i + limit, len(text))
        if end < len(text):
            for sep in [". ", ".\n", "! ", "? "]:
                k = text.rfind(sep, i, end)
                if k > i + 200:
                    end = k + len(sep)
                    break
        chunks.append(text[i:end].strip())
        i = end
    log(f"Split text into {len(chunks)} chunks of up to {limit} characters")
    return [c for c in chunks if c]

def invoke_anthropic_profile(profile_id, user_text, max_tokens=4000, temperature=0.0):
    body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": max_tokens,
        "temperature": temperature,
        "messages": [{"role": "user", "content": [{"type": "text", "text": user_text}]}],
    }
    resp = bedrock.invoke_model(modelId=profile_id, body=json.dumps(body))
    data = json.loads(resp["body"].read())
    return (data.get("content", [{}])[0].get("text") or "").strip()

def llm_is_english(sample_text):
    log("Checking language of text with LLM fallback...")
    q = "Answer with exactly 'en' if the text is English, otherwise 'non-en'. Text:\n\n" + sample_text[:2000]
    try:
        out = invoke_anthropic_profile(PROFILE_IDS["anthropic_haiku_4_5"], q, max_tokens=5)
        return out.strip().lower().startswith("en")
    except Exception as e:
        log(f"LLM language check (Haiku) failed: {e}")
        try:
            out = invoke_anthropic_profile(PROFILE_IDS["anthropic_sonnet_4_5"], q, max_tokens=5)
            return out.strip().lower().startswith("en")
        except Exception as e2:
            log(f"LLM language check (Sonnet) failed: {e2}")
            return False

def corpus_is_english(text):
    t = (text or "").strip()
    if not t:
        return True
    try:
        lang = detect(t[:10000])
        log(f"Detected language via langdetect: {lang}")
        if str(lang).lower() == "en":
            return True
    except Exception as e:
        log(f"langdetect failed: {e}")
    first_chunk = chunk_text(t, limit=MAX_CHUNK_CHARS)[:1]
    if first_chunk:
        result = llm_is_english(first_chunk[0])
        log(f"LLM language detection result: {'English' if result else 'Non-English'}")
        return result
    return False

def translate_chunks_parallel(chunks, max_workers=10):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        translated_chunks = list(executor.map(translate_chunk, chunks))
    return translated_chunks

def translate_chunk(text):
    try:
        pid = PROFILE_IDS["anthropic_haiku_4_5"]
        prompt = f"Translate this text to precise legal English. Preserve headings, numbering, and dates. No commentary.\n\n{text}"
        out = invoke_anthropic_profile(pid, prompt)
        if out:
            return out
    except Exception as e:
        log(f"Anthropic Haiku translation failed: {e}")
    try:
        pid = PROFILE_IDS["anthropic_sonnet_4_5"]
        prompt = f"Translate this text to precise legal English. Preserve headings, numbering, and dates. No commentary.\n\n{text}"
        out = invoke_anthropic_profile(pid, prompt)
        if out:
            return out
    except Exception as e:
        log(f"Anthropic Sonnet translation failed: {e}")
    return text

def process_file(file_path):
    print(f"Processing: {file_path.name}")
    raw = file_path.read_text(encoding="utf-8", errors="ignore")
    text = html_to_text(raw)
    chunks = chunk_text(text)
    print(f"  Translating {len(chunks)} chunks en parallèle")
    translated_chunks = translate_chunks_parallel(chunks, max_workers=8)
    final_text = "\n\n".join(translated_chunks)
    out_dir = Path(OUT_DIR)
    out_dir.mkdir(parents=True, exist_ok=True)
    out_file = out_dir / f"{file_path.stem}.txt"
    out_file.write_text(final_text, encoding="utf-8")
    print(f"Saved: {out_file.name}")

def process_file(file_path):
    log(f"Processing: {file_path.name}")
    raw = file_path.read_text(encoding="utf-8", errors="ignore")
    text = html_to_text(raw)
    if corpus_is_english(text):
        log("Document is already in English. Skipping translation.")
        final_text = text
    else:
        log("Document is NOT in English. Starting translation process...")
        chunks = chunk_text(text)
        translated_chunks = []
        print(f"  Translating {len(chunks)} chunks")
        translated_chunks = translate_chunks_parallel(chunks, max_workers=10)
        final_text = "\n\n".join(translated_chunks)
        log("Translation completed successfully.")
    out_dir = Path(OUT_DIR)
    out_dir.mkdir(parents=True, exist_ok=True)
    out_file = out_dir / f"{file_path.stem}.txt"
    out_file.write_text(final_text, encoding="utf-8")
    log(f"Saved translated text to {out_file.name}")

def main():
    files = get_files()
    log(f"Found {len(files)} files to process.")
    for file_path in files:
        process_file(file_path)
    log("All files processed.")

if __name__ == "__main__":
    main()
# Out:
# [LOG] Detected 1 eligible files in directives folder
# [LOG] Found 1 files to process.
# [LOG] Processing: 2.H.R.1 - One Big Beautiful Bill Act.xml
# [LOG] Extracted 892778 characters of text from HTML
# [LOG] Detected language via langdetect: en
# [LOG] Document is already in English. Skipping translation.
# [LOG] Saved translated text to 2.H.R.1 - One Big Beautiful Bill Act.txt
# [LOG] All files processed.

# %% [markdown]
# # Chunk Cleaning

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk) (2025.10.23)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from nltk) (4.67.1)

# %%
from pathlib import Path
from nltk.tokenize import wordpunct_tokenize

def clean_text(text):
    tokens = wordpunct_tokenize(text)
    tokens = [t for t in tokens if any(ch.isalnum() for ch in t)]
    return " ".join(tokens)

def process_translations(in_dir="out/translate", out_dir="out/processed"):
    in_path = Path(in_dir)
    out_path = Path(out_dir)
    out_path.mkdir(parents=True, exist_ok=True)
    for f in in_path.glob("*.txt"):
        raw = f.read_text(encoding="utf-8", errors="ignore")
        cleaned = clean_text(raw)
        (out_path / f.name).write_text(cleaned, encoding="utf-8")

if __name__ == "__main__":
    process_translations()

# %% [markdown]
# # Results Section

# %% [markdown]
# # Setup, config, helpers (files, chunking, Bedrock calls, JSON safety, dates)

# %%
# %% [markdown]
# ## 1) Setup, configuration & helper utilities
# - Constants, AWS Bedrock client, logging
# - Text chunking (sentence-aware up to MAX_CHUNK_CHARS)
# - Anthropic/Bedrock invocation with simple retries
# - Robust JSON cleaning/loading (handles ``` fences, smart quotes, extra text)
# - Date helpers + header date extraction heuristic

# %%
import json, time, re
from datetime import datetime
from pathlib import Path
import boto3
from botocore.config import Config
from concurrent.futures import ThreadPoolExecutor

AWS_REGION = "us-west-2"
IN_DIR = "out/processed"
OUT_DIR = "out/results"
MAX_CHUNK_CHARS = 4000

PROFILE_IDS = {
    "anthropic_haiku_4_5": "global.anthropic.claude-haiku-4-5-20251001-v1:0",
    "anthropic_sonnet_4_5": "global.anthropic.claude-sonnet-4-5-20250929-v1:0",
    "anthropic_sonnet_4": "global.anthropic.claude-sonnet-4-20250514-v1:0"
}

bedrock = boto3.client(
    "bedrock-runtime",
    region_name=AWS_REGION,
    config=Config(read_timeout=60, retries={"max_attempts": 3})
)

def log(msg): print(f"[LOG] {msg}")
def pct(n, d): return 0 if d == 0 else round(100 * n / d, 1)

def chunk_text(text, limit=MAX_CHUNK_CHARS):
    chunks, i = [], 0
    while i < len(text):
        end = min(i + limit, len(text))
        if end < len(text):
            for sep in [". ", ".\n", "! ", "? "]:
                k = text.rfind(sep, i, end)
                if k > i + 200:
                    end = k + len(sep)
                    break
        chunks.append(text[i:end].strip())
        i = end
    return [c for c in chunks if c]

def invoke_anthropic_profile(profile_id, user_text, max_tokens=2000, temperature=0.0):
    body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": max_tokens,
        "temperature": temperature,
        "messages": [{"role": "user", "content": [{"type": "text", "text": user_text}]}]
    }
    for attempt in range(3):
        try:
            resp = bedrock.invoke_model(modelId=profile_id, body=json.dumps(body))
            data = json.loads(resp["body"].read())
            return (data.get("content", [{}])[0].get("text") or "").strip()
        except Exception as e:
            log(f"LLM call failed (attempt {attempt+1}): {e}")
            time.sleep(1 + attempt)
    return ""

def _normalize_json_text(s):
    if not s: return ""
    s = (s.replace("\u2018","'").replace("\u2019","'")
           .replace("\u201C",'"').replace("\u201D",'"')
           .replace("\u00AB",'"').replace("\u00BB",'"')).strip()
    s = re.sub(r"^```(?:json)?", "", s, flags=re.IGNORECASE).strip()
    s = re.sub(r"```$", "", s).strip()
    m = re.search(r"[\{\[]", s)
    return s[m.start():] if m else s

def _find_balanced_json(s):
    # Fixed version: finds the first balanced JSON object/array substring
    s = s.strip()
    if not s: return ""
    start = None
    for i, ch in enumerate(s):
        if ch in "{[":
            start = i
            break
    if start is None: return ""
    stack = []
    in_str = False
    esc = False
    for j in range(start, len(s)):
        ch = s[j]
        if in_str:
            if esc:
                esc = False
            elif ch == "\\":
                esc = True
            elif ch == '"':
                in_str = False
            continue
        else:
            if ch == '"':
                in_str = True
                continue
            if ch in "{[":
                stack.append(ch)
            elif ch in "}]":
                if not stack:
                    return ""
                top = stack.pop()
                if (top == "{" and ch != "}") or (top == "[" and ch != "]"):
                    return ""
                if not stack:
                    return s[start:j+1]
    return ""

def safe_load_json(raw, expect_object=True):
    if not raw: return None
    txt = _normalize_json_text(raw)
    try:
        obj = json.loads(txt)
        if expect_object and not isinstance(obj, dict): return None
        return obj
    except Exception:
        pass
    seg = _find_balanced_json(txt)
    if not seg: return None
    try:
        obj = json.loads(seg)
        if expect_object and not isinstance(obj, dict): return None
        return obj
    except Exception:
        return None

MONTHS = {
    "january":1,"february":2,"march":3,"april":4,"may":5,"june":6,
    "july":7,"august":8,"september":9,"october":10,"november":11,"december":12
}
HEADER_RE = re.compile(
    r"(DIRECTIVE|REGULATION|DECISION)[^\n]{0,300}?\bOF\b\s+(\d{1,2}\s+[A-Za-z]+\s+\d{4})",
    re.IGNORECASE | re.DOTALL
)

def _to_iso_date(s):
    s = s.strip()
    if re.match(r"^\d{4}(-\d{2}(-\d{2})?)?$", s):
        y = int(s[:4])
        if 1950 <= y <= datetime.utcnow().year + 1:
            return s
        return ""
    m = re.match(r"^(\d{1,2})\s+([A-Za-z]+)\s+(\d{4})$", s)
    if m:
        d = int(m.group(1)); mon = MONTHS.get(m.group(2).lower()); y = int(m.group(3))
        if mon and 1 <= d <= 31 and 1950 <= y <= datetime.utcnow().year + 1:
            return f"{y:04d}-{mon:02d}-{d:02d}"
    return ""

def _header_date(text):
    head = text[:2000].replace("\u00A0"," ").replace("\u202F"," ")
    m = HEADER_RE.search(head)
    if not m: return ""
    return _to_iso_date(m.group(2)) or ""

# %% [markdown]
# # Prompts, state model, per-chunk worker, parallel extraction

# %%
# %% [markdown]
# ## 2) Prompt builders, state merging, per-chunk worker, parallel extraction
# - JSON-only prompts for date refinement and state updates
# - State containers + merge logic (dedup, case-insensitive sort)
# - Worker function processes one chunk (date probe + state update)
# - `extract_from_chunks_parallel`: drives ThreadPoolExecutor over all chunks

# %%
def empty_state():
    return {
        "date": None,
        "jurisdiction_country": [],
        "sector": [],
        "activity": [],
        "regulatory_domain": [],
        "impact_type": [],
        "regulator_entity": []
    }

def empty_date_info():
    return {"date": None, "specificity": 0, "evidence_chunk": "", "locked": False, "law_header": ""}

def merge_state(state, update):
    for k in ["jurisdiction_country","sector","activity","regulatory_domain","impact_type","regulator_entity"]:
        seen = set(state.get(k) or [])
        for v in (update.get(k,[]) or []):
            v = (v or "").strip()
            if v:
                seen.add(v)
        state[k] = sorted(seen, key=lambda x: x.lower())
    return state

def build_state_prompt(law_id, prior_state_json, current_date, date_evidence, law_header, chunk_text):
    return f"""Return ONLY a JSON object with keys: "date","jurisdiction_country","sector","activity","regulatory_domain","impact_type","regulator_entity".
Rules:
- law_id is {law_id} and must NOT appear in output.
- Do not change "date". If you include "date", it MUST equal CURRENT_DATE or be a strictly more specific ISO refinement of the SAME year and month.
- For list fields, add unique strings supported by this chunk; do not remove prior values.

LAW_HEADER:
{law_header}

CURRENT_STATE:
{prior_state_json}

CURRENT_DATE_CONTEXT:
date: {current_date or ""}
evidence_chunk: {date_evidence or ""}

CHUNK:
{chunk_text}"""

def build_date_probe_prompt(law_id, law_header, current_date, current_specificity, chunk_text):
    return f"""Return ONLY JSON: {{"date":"","specificity":0,"is_stronger":false,"same_law":false,"confidence":0.0,"evidence":""}}.
- Consider ONLY dates that refer to THIS law (not citations to other instruments).
- same_law: true only if the chunk clearly ties the date to THIS law identified by law_id and header.
- confidence: 0..1 for that judgment.
- specificity: 3=YYYY-MM-DD, 2=YYYY-MM, 1=YYYY, 0=unknown.
- is_stronger: true only if same_law is true AND the candidate is more specific than CURRENT_DATE and same year.

law_id: {law_id}
law_header: {law_header}

CURRENT_DATE: {current_date or ""} (specificity={current_specificity})
CHUNK:
{chunk_text}"""

def call_json(prompt, expect_object=True, max_tokens=800):
    for pid in [
        PROFILE_IDS["anthropic_haiku_4_5"],
        PROFILE_IDS["anthropic_sonnet_4_5"],
        PROFILE_IDS["anthropic_sonnet_4"]
    ]:
        out = invoke_anthropic_profile(pid, prompt, max_tokens=max_tokens)
        obj = safe_load_json(out, expect_object=expect_object)
        if obj is not None:
            return obj
    return None

def process_single_chunk(args):
    idx, ch, law_id, date_info, state = args

    # deepcopy to isolate thread state
    import copy
    date_info = copy.deepcopy(date_info)
    state = copy.deepcopy(state)

    result = {}

    # Date probe (only if not locked)
    if not date_info.get("locked"):
        dprobe = call_json(build_date_probe_prompt(
            law_id,
            date_info.get("law_header", ""),
            date_info.get("date", ""),
            date_info.get("specificity", 0),
            ch
        ), expect_object=True, max_tokens=320)

        if isinstance(dprobe, dict):
            cand = _to_iso_date((dprobe.get("date") or "").strip())
            spec = int(dprobe.get("specificity") or 0)
            stronger = bool(dprobe.get("is_stronger"))
            same_law = bool(dprobe.get("same_law"))
            conf = float(dprobe.get("confidence") or 0.0)
            # Accept if clearly tied to the same law and confident
            if cand and same_law and conf >= 0.8:
                result["date"] = cand
                result["specificity"] = spec

    # State update
    sprompt = build_state_prompt(
        law_id,
        json.dumps({**state, "date": date_info.get("date", "")}, ensure_ascii=False),
        date_info.get("date", ""), date_info.get("evidence_chunk", ""),
        date_info.get("law_header", ""), ch
    )
    supd = call_json(sprompt, expect_object=True, max_tokens=800)
    result["state"] = supd if isinstance(supd, dict) else {}

    return idx, result

def extract_from_chunks_parallel(law_id, text):
    state = empty_state()
    date_info = empty_date_info()

    # Header date heuristic
    hd = _header_date(text)
    if hd:
        date_info["date"] = hd
        date_info["specificity"] = 3
        date_info["evidence_chunk"] = text[:2000]
        date_info["locked"] = True
        log(f"Date chosen (header) for {law_id}: {hd}")
    else:
        log(f"No header date found for {law_id}")

    chunks = chunk_text(text)
    if chunks:
        date_info["law_header"] = chunks[0][:1000]
    total = len(chunks)

    args_list = [(idx, ch, law_id, date_info, state) for idx, ch in enumerate(chunks, 1)]

    # Use a reasonable pool size to avoid throttling (tune as needed)
    max_workers = min(20, (os_cpu := __import__("os").cpu_count() or 4) * 5)
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for idx, result in executor.map(process_single_chunk, args_list):
            # Date merge (prefer more specific)
            if "date" in result and result["date"]:
                if (not date_info["date"]) or (len(result["date"]) > len(date_info["date"])):
                    date_info["date"] = result["date"]
                    date_info["specificity"] = result.get("specificity", date_info["specificity"])
                    date_info["evidence_chunk"] = chunks[idx - 1][:2000]
                    date_info["locked"] = True
            # State merge
            if "state" in result and isinstance(result["state"], dict):
                state = merge_state(state, result["state"])
            log(f"Progress {law_id}: {idx}/{total} ({pct(idx, total)}%)")

    if date_info.get("date"):
        state["date"] = date_info["date"]
        log(f"Final date for {law_id}: {date_info['date']}")
    else:
        log(f"No date resolved for {law_id}")

    return state

# %% [markdown]
# # I/O (CSV) & batch orchestration

# %%
# %% [markdown]
# ## 3) I/O (CSV) & batch orchestration
# - Writes one CSV per law with a single row (lists joined by semicolons)
# - Iterates over `out/processed/*.txt`, runs extraction, logs progress
# - Main guard to run the batch

# %%
def write_csv_row(path, row):
    path.parent.mkdir(parents=True, exist_ok=True)
    headers = ["law_id","date","jurisdiction_country","sector","activity","regulatory_domain","impact_type","regulator_entity"]
    def join(v):
        if v is None: return ""
        if isinstance(v, list): return ";".join(v)
        return str(v)
    with path.open("w", encoding="utf-8") as f:
        f.write(",".join(headers) + "\n")
        f.write(",".join([
            row.get("law_id",""),
            row.get("date","") or "",
            join(row.get("jurisdiction_country", [])),
            join(row.get("sector", [])),
            join(row.get("activity", [])),
            join(row.get("regulatory_domain", [])),
            join(row.get("impact_type", [])),
            join(row.get("regulator_entity", []))
        ]) + "\n")

def process_all():
    in_dir = Path(IN_DIR)
    out_dir = Path(OUT_DIR)
    out_dir.mkdir(parents=True, exist_ok=True)
    files = sorted(in_dir.glob("*.txt"))
    total = len(files)
    done = 0
    log(f"Found {total} files in {IN_DIR}")
    for f in files:
        law_id = f.stem
        log(f"Start processing {law_id}")
        text = f.read_text(encoding="utf-8", errors="ignore")
        # Use the defined parallel extractor
        state = extract_from_chunks_parallel(law_id, text)
        row = {"law_id": law_id, **state}
        write_csv_row(out_dir / f"{law_id}.csv", row)
        done += 1
        log(f"Completed {law_id} ({pct(done, total)}%)")
    log("All files processed.")

if __name__ == "__main__":
    process_all()
# Out:
# [LOG] Found 6 files in out/processed
# [LOG] Start processing 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL
# [LOG] Date chosen (header) for 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 2019-11-27
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 1/23 (4.3%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 2/23 (8.7%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 3/23 (13.0%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 4/23 (17.4%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 5/23 (21.7%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 6/23 (26.1%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 7/23 (30.4%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 8/23 (34.8%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 9/23 (39.1%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 10/23 (43.5%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 11/23 (47.8%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 12/23 (52.2%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 13/23 (56.5%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 14/23 (60.9%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 15/23 (65.2%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 16/23 (69.6%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 17/23 (73.9%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 18/23 (78.3%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 19/23 (82.6%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 20/23 (87.0%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 21/23 (91.3%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 22/23 (95.7%)
# [LOG] Progress 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 23/23 (100.0%)
# [LOG] Final date for 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL: 2019-11-27
# [LOG] Completed 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (16.7%)
# [LOG] Start processing 2.H.R.1 - One Big Beautiful Bill Act
# [LOG] No header date found for 2.H.R.1 - One Big Beautiful Bill Act
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 1/210 (0.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 2/210 (1.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 3/210 (1.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 4/210 (1.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 5/210 (2.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 6/210 (2.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 7/210 (3.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 8/210 (3.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 9/210 (4.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 10/210 (4.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 11/210 (5.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 12/210 (5.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 13/210 (6.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 14/210 (6.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 15/210 (7.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 16/210 (7.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 17/210 (8.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 18/210 (8.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 19/210 (9.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 20/210 (9.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 21/210 (10.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 22/210 (10.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 23/210 (11.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 24/210 (11.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 25/210 (11.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 26/210 (12.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 27/210 (12.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 28/210 (13.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 29/210 (13.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 30/210 (14.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 31/210 (14.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 32/210 (15.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 33/210 (15.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 34/210 (16.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 35/210 (16.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 36/210 (17.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 37/210 (17.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 38/210 (18.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 39/210 (18.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 40/210 (19.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 41/210 (19.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 42/210 (20.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 43/210 (20.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 44/210 (21.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 45/210 (21.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 46/210 (21.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 47/210 (22.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 48/210 (22.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 49/210 (23.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 50/210 (23.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 51/210 (24.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 52/210 (24.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 53/210 (25.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 54/210 (25.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 55/210 (26.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 56/210 (26.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 57/210 (27.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 58/210 (27.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 59/210 (28.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 60/210 (28.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 61/210 (29.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 62/210 (29.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 63/210 (30.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 64/210 (30.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 65/210 (31.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 66/210 (31.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 67/210 (31.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 68/210 (32.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 69/210 (32.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 70/210 (33.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 71/210 (33.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 72/210 (34.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 73/210 (34.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 74/210 (35.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 75/210 (35.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 76/210 (36.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 77/210 (36.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 78/210 (37.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 79/210 (37.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 80/210 (38.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 81/210 (38.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 82/210 (39.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 83/210 (39.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 84/210 (40.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 85/210 (40.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 86/210 (41.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 87/210 (41.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 88/210 (41.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 89/210 (42.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 90/210 (42.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 91/210 (43.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 92/210 (43.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 93/210 (44.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 94/210 (44.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 95/210 (45.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 96/210 (45.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 97/210 (46.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 98/210 (46.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 99/210 (47.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 100/210 (47.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 101/210 (48.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 102/210 (48.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 103/210 (49.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 104/210 (49.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 105/210 (50.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 106/210 (50.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 107/210 (51.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 108/210 (51.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 109/210 (51.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 110/210 (52.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 111/210 (52.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 112/210 (53.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 113/210 (53.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 114/210 (54.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 115/210 (54.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 116/210 (55.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 117/210 (55.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 118/210 (56.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 119/210 (56.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 120/210 (57.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 121/210 (57.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 122/210 (58.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 123/210 (58.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 124/210 (59.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 125/210 (59.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 126/210 (60.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 127/210 (60.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 128/210 (61.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 129/210 (61.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 130/210 (61.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 131/210 (62.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 132/210 (62.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 133/210 (63.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 134/210 (63.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 135/210 (64.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 136/210 (64.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 137/210 (65.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 138/210 (65.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 139/210 (66.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 140/210 (66.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 141/210 (67.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 142/210 (67.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 143/210 (68.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 144/210 (68.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 145/210 (69.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 146/210 (69.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 147/210 (70.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 148/210 (70.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 149/210 (71.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 150/210 (71.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 151/210 (71.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 152/210 (72.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 153/210 (72.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 154/210 (73.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 155/210 (73.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 156/210 (74.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 157/210 (74.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 158/210 (75.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 159/210 (75.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 160/210 (76.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 161/210 (76.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 162/210 (77.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 163/210 (77.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 164/210 (78.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 165/210 (78.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 166/210 (79.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 167/210 (79.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 168/210 (80.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 169/210 (80.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 170/210 (81.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 171/210 (81.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 172/210 (81.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 173/210 (82.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 174/210 (82.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 175/210 (83.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 176/210 (83.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 177/210 (84.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 178/210 (84.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 179/210 (85.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 180/210 (85.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 181/210 (86.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 182/210 (86.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 183/210 (87.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 184/210 (87.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 185/210 (88.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 186/210 (88.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 187/210 (89.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 188/210 (89.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 189/210 (90.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 190/210 (90.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 191/210 (91.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 192/210 (91.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 193/210 (91.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 194/210 (92.4%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 195/210 (92.9%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 196/210 (93.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 197/210 (93.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 198/210 (94.3%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 199/210 (94.8%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 200/210 (95.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 201/210 (95.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 202/210 (96.2%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 203/210 (96.7%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 204/210 (97.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 205/210 (97.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 206/210 (98.1%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 207/210 (98.6%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 208/210 (99.0%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 209/210 (99.5%)
# [LOG] Progress 2.H.R.1 - One Big Beautiful Bill Act: 210/210 (100.0%)
# [LOG] Final date for 2.H.R.1 - One Big Beautiful Bill Act: 2025-07-04
# [LOG] Completed 2.H.R.1 - One Big Beautiful Bill Act (33.3%)
# [LOG] Start processing 3.H.R.5376 - Inflation Reduction Act of 2022
# [LOG] No header date found for 3.H.R.5376 - Inflation Reduction Act of 2022
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 1/177 (0.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 2/177 (1.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 3/177 (1.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 4/177 (2.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 5/177 (2.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 6/177 (3.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 7/177 (4.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 8/177 (4.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 9/177 (5.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 10/177 (5.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 11/177 (6.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 12/177 (6.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 13/177 (7.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 14/177 (7.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 15/177 (8.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 16/177 (9.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 17/177 (9.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 18/177 (10.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 19/177 (10.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 20/177 (11.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 21/177 (11.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 22/177 (12.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 23/177 (13.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 24/177 (13.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 25/177 (14.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 26/177 (14.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 27/177 (15.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 28/177 (15.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 29/177 (16.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 30/177 (16.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 31/177 (17.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 32/177 (18.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 33/177 (18.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 34/177 (19.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 35/177 (19.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 36/177 (20.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 37/177 (20.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 38/177 (21.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 39/177 (22.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 40/177 (22.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 41/177 (23.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 42/177 (23.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 43/177 (24.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 44/177 (24.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 45/177 (25.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 46/177 (26.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 47/177 (26.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 48/177 (27.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 49/177 (27.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 50/177 (28.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 51/177 (28.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 52/177 (29.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 53/177 (29.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 54/177 (30.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 55/177 (31.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 56/177 (31.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 57/177 (32.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 58/177 (32.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 59/177 (33.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 60/177 (33.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 61/177 (34.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 62/177 (35.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 63/177 (35.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 64/177 (36.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 65/177 (36.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 66/177 (37.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 67/177 (37.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 68/177 (38.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 69/177 (39.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 70/177 (39.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 71/177 (40.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 72/177 (40.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 73/177 (41.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 74/177 (41.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 75/177 (42.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 76/177 (42.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 77/177 (43.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 78/177 (44.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 79/177 (44.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 80/177 (45.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 81/177 (45.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 82/177 (46.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 83/177 (46.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 84/177 (47.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 85/177 (48.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 86/177 (48.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 87/177 (49.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 88/177 (49.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 89/177 (50.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 90/177 (50.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 91/177 (51.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 92/177 (52.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 93/177 (52.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 94/177 (53.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 95/177 (53.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 96/177 (54.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 97/177 (54.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 98/177 (55.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 99/177 (55.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 100/177 (56.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 101/177 (57.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 102/177 (57.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 103/177 (58.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 104/177 (58.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 105/177 (59.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 106/177 (59.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 107/177 (60.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 108/177 (61.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 109/177 (61.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 110/177 (62.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 111/177 (62.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 112/177 (63.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 113/177 (63.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 114/177 (64.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 115/177 (65.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 116/177 (65.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 117/177 (66.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 118/177 (66.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 119/177 (67.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 120/177 (67.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 121/177 (68.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 122/177 (68.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 123/177 (69.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 124/177 (70.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 125/177 (70.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 126/177 (71.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 127/177 (71.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 128/177 (72.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 129/177 (72.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 130/177 (73.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 131/177 (74.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 132/177 (74.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 133/177 (75.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 134/177 (75.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 135/177 (76.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 136/177 (76.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 137/177 (77.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 138/177 (78.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 139/177 (78.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 140/177 (79.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 141/177 (79.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 142/177 (80.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 143/177 (80.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 144/177 (81.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 145/177 (81.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 146/177 (82.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 147/177 (83.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 148/177 (83.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 149/177 (84.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 150/177 (84.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 151/177 (85.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 152/177 (85.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 153/177 (86.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 154/177 (87.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 155/177 (87.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 156/177 (88.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 157/177 (88.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 158/177 (89.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 159/177 (89.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 160/177 (90.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 161/177 (91.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 162/177 (91.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 163/177 (92.1%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 164/177 (92.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 165/177 (93.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 166/177 (93.8%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 167/177 (94.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 168/177 (94.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 169/177 (95.5%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 170/177 (96.0%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 171/177 (96.6%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 172/177 (97.2%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 173/177 (97.7%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 174/177 (98.3%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 175/177 (98.9%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 176/177 (99.4%)
# [LOG] Progress 3.H.R.5376 - Inflation Reduction Act of 2022: 177/177 (100.0%)
# [LOG] Final date for 3.H.R.5376 - Inflation Reduction Act of 2022: 2022-08-16
# [LOG] Completed 3.H.R.5376 - Inflation Reduction Act of 2022 (50.0%)
# [LOG] Start processing 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL
# [LOG] Date chosen (header) for 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 2024-06-13
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 1/143 (0.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 2/143 (1.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 3/143 (2.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 4/143 (2.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 5/143 (3.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 6/143 (4.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 7/143 (4.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 8/143 (5.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 9/143 (6.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 10/143 (7.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 11/143 (7.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 12/143 (8.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 13/143 (9.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 14/143 (9.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 15/143 (10.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 16/143 (11.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 17/143 (11.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 18/143 (12.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 19/143 (13.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 20/143 (14.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 21/143 (14.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 22/143 (15.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 23/143 (16.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 24/143 (16.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 25/143 (17.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 26/143 (18.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 27/143 (18.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 28/143 (19.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 29/143 (20.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 30/143 (21.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 31/143 (21.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 32/143 (22.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 33/143 (23.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 34/143 (23.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 35/143 (24.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 36/143 (25.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 37/143 (25.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 38/143 (26.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 39/143 (27.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 40/143 (28.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 41/143 (28.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 42/143 (29.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 43/143 (30.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 44/143 (30.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 45/143 (31.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 46/143 (32.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 47/143 (32.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 48/143 (33.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 49/143 (34.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 50/143 (35.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 51/143 (35.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 52/143 (36.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 53/143 (37.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 54/143 (37.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 55/143 (38.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 56/143 (39.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 57/143 (39.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 58/143 (40.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 59/143 (41.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 60/143 (42.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 61/143 (42.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 62/143 (43.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 63/143 (44.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 64/143 (44.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 65/143 (45.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 66/143 (46.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 67/143 (46.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 68/143 (47.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 69/143 (48.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 70/143 (49.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 71/143 (49.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 72/143 (50.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 73/143 (51.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 74/143 (51.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 75/143 (52.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 76/143 (53.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 77/143 (53.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 78/143 (54.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 79/143 (55.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 80/143 (55.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 81/143 (56.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 82/143 (57.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 83/143 (58.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 84/143 (58.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 85/143 (59.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 86/143 (60.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 87/143 (60.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 88/143 (61.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 89/143 (62.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 90/143 (62.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 91/143 (63.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 92/143 (64.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 93/143 (65.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 94/143 (65.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 95/143 (66.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 96/143 (67.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 97/143 (67.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 98/143 (68.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 99/143 (69.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 100/143 (69.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 101/143 (70.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 102/143 (71.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 103/143 (72.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 104/143 (72.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 105/143 (73.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 106/143 (74.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 107/143 (74.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 108/143 (75.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 109/143 (76.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 110/143 (76.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 111/143 (77.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 112/143 (78.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 113/143 (79.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 114/143 (79.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 115/143 (80.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 116/143 (81.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 117/143 (81.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 118/143 (82.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 119/143 (83.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 120/143 (83.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 121/143 (84.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 122/143 (85.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 123/143 (86.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 124/143 (86.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 125/143 (87.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 126/143 (88.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 127/143 (88.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 128/143 (89.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 129/143 (90.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 130/143 (90.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 131/143 (91.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 132/143 (92.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 133/143 (93.0%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 134/143 (93.7%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 135/143 (94.4%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 136/143 (95.1%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 137/143 (95.8%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 138/143 (96.5%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 139/143 (97.2%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 140/143 (97.9%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 141/143 (98.6%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 142/143 (99.3%)
# [LOG] Progress 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 143/143 (100.0%)
# [LOG] Final date for 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL: 2024-06-13
# [LOG] Completed 4.REGULATION (EU) 20241689 OF THE EUROPEAN PARLIAMENT AND OF THE COUNCIL (66.7%)
# [LOG] Start processing 5.中华人民共和国能源法__中国政府网
# [LOG] No header date found for 5.中华人民共和国能源法__中国政府网
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 1/21 (4.8%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 2/21 (9.5%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 3/21 (14.3%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 4/21 (19.0%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 5/21 (23.8%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 6/21 (28.6%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 7/21 (33.3%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 8/21 (38.1%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 9/21 (42.9%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 10/21 (47.6%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 11/21 (52.4%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 12/21 (57.1%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 13/21 (61.9%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 14/21 (66.7%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 15/21 (71.4%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 16/21 (76.2%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 17/21 (81.0%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 18/21 (85.7%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 19/21 (90.5%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 20/21 (95.2%)
# [LOG] Progress 5.中华人民共和国能源法__中国政府网: 21/21 (100.0%)
# [LOG] Final date for 5.中华人民共和国能源法__中国政府网: 2024-11-08
# [LOG] Completed 5.中华人民共和国能源法__中国政府网 (83.3%)
# [LOG] Start processing 6.人工知能関連技術の研究開発及び活用の推進に関する法律
# [LOG] No header date found for 6.人工知能関連技術の研究開発及び活用の推進に関する法律
# [LOG] Progress 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 1/5 (20.0%)
# [LOG] Progress 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 2/5 (40.0%)
# [LOG] Progress 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 3/5 (60.0%)
# [LOG] Progress 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 4/5 (80.0%)
# [LOG] Progress 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 5/5 (100.0%)
# [LOG] Final date for 6.人工知能関連技術の研究開発及び活用の推進に関する法律: 2025
# [LOG] Completed 6.人工知能関連技術の研究開発及び活用の推進に関する法律 (100.0%)
# [LOG] All files processed.
