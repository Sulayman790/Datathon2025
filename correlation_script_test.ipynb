# %% [markdown]
# # Correlation Script Test - SEC x Regulations Field-by-Field Matching
#
# This notebook tests field-by-field correlation between SEC company data and regulations using Jaccard similarity.

# %%
import pandas as pd
import re
from pathlib import Path
from datetime import datetime
import os

os.makedirs('/home/sagemaker-user/shared/outputs', exist_ok=True)

# %% [markdown]
# ## Configuration and Helper Functions

# %%
COMP_PATH = Path("/home/sagemaker-user/shared/outputs/sec_matrix.csv")
REGS_PATH = Path("/home/sagemaker-user/shared/regulations_example.csv")
OUT_PATH = Path("/home/sagemaker-user/shared/outputs/sec_x_laws_matches_strong.csv")

def normalize_sector(x: str) -> str:
    if not isinstance(x, str): 
        return ""
    xl = x.strip().lower()
    aliases = {
        "tech": "information technology",
        "it": "information technology",
        "healthcare": "health care",
        "finance": "financials"
    }
    return aliases.get(xl, xl)

def tokenize(s: str):
    if not isinstance(s, str) or not s.strip():
        return set()
    return set(re.findall(r"[a-z0-9\-\+_/]+", s.lower()))

def jaccard(a: str, b: str) -> float:
    ta, tb = tokenize(a), tokenize(b)
    if not ta and not tb:
        return 0.0
    inter = len(ta & tb)
    uni = len(ta | tb)
    return inter / uni if uni else 0.0

def date_overlap(sa, ea, sb, eb) -> float:
    def parse(x):
        try:
            return datetime.fromisoformat(x) if x and isinstance(x, str) else None
        except Exception:
            return None
    sa, ea, sb, eb = parse(sa), parse(ea), parse(sb), parse(eb)
    if sa is None and ea is None and sb is None and eb is None:
        return 0.0
    ea = ea or datetime.max
    eb = eb or datetime.max
    sa = sa or datetime.min
    sb = sb or datetime.min
    latest_start = max(sa, sb)
    earliest_end = min(ea, eb)
    overlap = (earliest_end - latest_start).days
    if overlap <= 0:
        return 0.0
    union = (max(ea, eb) - min(sa, sb)).days
    return max(0.0, min(1.0, overlap / union)) if union > 0 else 0.0

# %% [markdown]
# ## Test Similarity Functions

# %%
# Test similarity with sample data
test_cases = [
    ("US", "United States", "country"),
    ("USA", "United States", "country"),
    ("Technology", "Information Technology", "sector"),
    ("Healthcare", "Health Care Equipment & Services", "sector"),
    ("data processing", "consumer data", "activities")
]

print("Testing Jaccard Similarity Scores:")
for text1, text2, field_type in test_cases:
    jaccard_score = jaccard(text1, text2)
    print(f"{field_type}: '{text1}' vs '{text2}' -> Jaccard: {jaccard_score:.3f}")
# Out:
# Testing Jaccard Similarity Scores:
# country: 'US' vs 'United States' -> Jaccard: 0.000
# country: 'USA' vs 'United States' -> Jaccard: 0.000
# sector: 'Technology' vs 'Information Technology' -> Jaccard: 0.500
# sector: 'Healthcare' vs 'Health Care Equipment & Services' -> Jaccard: 0.000
# activities: 'data processing' vs 'consumer data' -> Jaccard: 0.333

# %% [markdown]
# ## Load and Inspect Data

# %%
print(f"SEC Matrix exists: {COMP_PATH.exists()}")
print(f"Regulations exists: {REGS_PATH.exists()}")

companies = pd.read_csv(COMP_PATH)
regulations = pd.read_csv(REGS_PATH)

print(f"\nCompanies data shape: {companies.shape}")
print(f"Companies columns: {list(companies.columns)}")
print("\nFirst few companies:")
print(companies.head(3))

print(f"\nRegulations data shape: {regulations.shape}")
print(f"Regulations columns: {list(regulations.columns)}")
print("\nFirst few regulations:")
print(regulations.head(3))
# Out:
# SEC Matrix exists: True
# Regulations exists: True
#
# Companies data shape: (500, 23)
# Companies columns: ['ticker', 'company', 'sector', 'headquarters_country', 'revenues_total_usd', 'revenue_by_region_notes', 'region_exposure_US', 'region_exposure_Europe', 'region_exposure_China', 'region_exposure_India', 'supply_chain_regions', 'key_suppliers', 'key_customers', 'critical_dependencies', 'regulatory_dependencies', 'sanctions_exposure', 'environmental_regulatory_risk', 'labor_regulatory_risk', 'cybersecurity_regulatory_risk', 'ai_governance_risk', 'overall_regulatory_risk_score', 'confidence', 'sources']
#
# First few companies:
#   ticker                     company                            sector  \
# 0      A  Agilent Technologies, Inc.  Health Care Equipment & Services
# 1   AAPL                  Apple Inc.                        Technology
# 2   ABBV                 AbbVie Inc.                        Healthcare
#
#   headquarters_country revenues_total_usd  \
# 0        United States         6830000000
# 1                   US       383285000000
# 2        United States        58853000000
#
#                              revenue_by_region_notes region_exposure_US  \
# 0         Americas 39%, Europe 26%, Asia Pacific 35%               high
# 1  Americas 43%, Europe 24%, Greater China 18%, J...               high
# 2          Specific regional breakdowns not provided               high
#
#   region_exposure_Europe region_exposure_China region_exposure_India  ...  \
# 0                 medium                  high                medium  ...
# 1                 medium                medium                   low  ...
# 2                 medium                   low                   low  ...
#
#                                critical_dependencies  \
# 0  Semiconductors; Rare earth elements; Specialty...
# 1  Semiconductors; Rare earth elements; Manufactu...
# 2  Research and development; Manufacturing; Intel...
#
#                              regulatory_dependencies  \
# 0  FDA regulations; Environmental regulations; Ex...
# 1  Data privacy laws; Antitrust regulations; Envi...
# 2  FDA approvals; International regulatory approvals
#
#                         sanctions_exposure environmental_regulatory_risk  \
# 0  Low exposure to Russia/Ukraine conflict                        medium
# 1    Low exposure to Russia/Iran sanctions                        medium
# 2                                  Unknown                        medium
#
#   labor_regulatory_risk cybersecurity_regulatory_risk ai_governance_risk  \
# 0                   low                        medium                low
# 1                medium                          high             medium
# 2                medium                        medium                low
#
#   overall_regulatory_risk_score confidence                  sources
# 0                          50.0        0.8  Item 1; Item 1A; Item 7
# 1                          65.0        0.8  Item 1; Item 1A; Item 7
# 2                          60.0        0.8  Item 1; Item 1A; Item 7
#
# [3 rows x 23 columns]
#
# Regulations data shape: (1, 8)
# Regulations columns: ['law_id', 'date', 'jurisdiction_country', 'sector', 'activity', 'regulatory_domain', 'impact_type', 'regulator_entity']
#
# First few regulations:
#                                               law_id        date  \
# 0  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...  2019-11-27
#
#   jurisdiction_country                                             sector  \
# 0       European Union  Consumer Protection;Cultural Events;Digital Co...
#
#                                             activity  \
# 0  Automated decision-making disclosure;Bot-based...
#
#                                    regulatory_domain  \
# 0  Automated decision-making;Bot regulation for t...
#
#                                          impact_type  \
# 0  Automated pricing transparency;Bot-based resal...
#
#                                     regulator_entity
# 0  Administrative authorities;Council of the Euro...

# %% [markdown]
# ## Run Correlation Analysis

# %%
# Helper functions
comp_cols = {c.lower(): c for c in companies.columns}

def get_company_field(row, logical):
    mapping = {
        "ticker": ["ticker"],
        "company_name": ["company","company_name","name"],
        "jurisdiction_country": ["jurisdiction_country","country","headquarters_country"],
        "sector": ["sector","gics_sector","industry"],
        "activities": ["activity","activities","business_function"],
        "regulatory_domain": ["regulatory_dependencies","regulatory_theme","theme"],
        "impact_type": ["impact_type","impact","risk_type"],
        "regulator_entity": ["regulator","regulator_entity"]
    }
    for cand in mapping.get(logical, []):
        if cand in comp_cols:
            val = row[comp_cols[cand]]
            if pd.notna(val):
                return val
    return ""

WEIGHTS = {
    "jurisdiction_country": 2.0,
    "sector": 1.8,
    "activities": 1.8,
    "regulatory_domain": 1.0,
    "impact_type": 0.8
}

print("Running correlation analysis...")
rows = []

for i, crow in companies.iterrows():
    c_name = get_company_field(crow, "company_name")
    c_ticker = get_company_field(crow, "ticker")
    c_country = str(get_company_field(crow, "jurisdiction_country"))
    c_sector = normalize_sector(str(get_company_field(crow, "sector")))
    c_acts = str(get_company_field(crow, "activities"))
    c_theme = str(get_company_field(crow, "regulatory_domain"))
    c_impact = str(get_company_field(crow, "impact_type"))
    c_reg = str(get_company_field(crow, "regulator_entity"))

    for j, rrow in regulations.iterrows():
        # Field-by-field correlation matching
        m_country = jaccard(c_country, str(rrow.get("jurisdiction_country","")))
        m_sector = jaccard(c_sector, normalize_sector(str(rrow.get("sector",""))))
        m_acts = jaccard(c_acts + " " + c_sector, str(rrow.get("activity","")))
        m_theme = jaccard(c_theme, str(rrow.get("regulatory_domain","")))
        m_impact = jaccard(c_impact, str(rrow.get("impact_type","")))
        m_reg = jaccard(c_reg, str(rrow.get("regulator_entity","")))

        score = (
            WEIGHTS["jurisdiction_country"] * m_country +
            WEIGHTS["sector"] * m_sector +
            WEIGHTS["activities"] * m_acts +
            WEIGHTS["regulatory_domain"] * m_theme +
            WEIGHTS["impact_type"] * m_impact
        )

        rows.append({
            "company_ticker": c_ticker,
            "company_name": c_name,
            "law_id": rrow.get("law_id",""),
            "country_match": round(m_country, 3),
            "sector_match": round(m_sector, 3),
            "activities_match": round(m_acts, 3),
            "domain_match": round(m_theme, 3),
            "impact_match": round(m_impact, 3),
            "regulator_match": round(m_reg, 3),
            "score_total": round(score, 4),
        })

print(f"Generated {len(rows)} correlation pairs")
# Out:
# Running correlation analysis...
# Generated 500 correlation pairs

# %% [markdown]
# ## Analyze Results

# %%
matches = pd.DataFrame(rows)

if not matches.empty:
    matches = matches.sort_values(["company_ticker","score_total"], ascending=[True, False]).reset_index(drop=True)
    matches.to_csv(OUT_PATH, index=False)
    
    print("\n=== TOP CORRELATIONS ===")
    print(matches.head(10))
    
    print("\n=== SCORE DISTRIBUTION ===")
    print(matches['score_total'].describe())
    
    print("\n=== TOP MATCHES BY COMPANY ===")
    for ticker in matches['company_ticker'].unique():
        company_matches = matches[matches['company_ticker'] == ticker].head(3)
        print(f"\n{ticker}:")
        for _, row in company_matches.iterrows():
            print(f"  {row['law_id']} ({row['score_total']:.3f}) - Country:{row['country_match']:.2f} Sector:{row['sector_match']:.2f}")
    
    print(f"\nResults saved to: {OUT_PATH}")
else:
    print("No matches generated")
# Out:
# === TOP CORRELATIONS ===
#   company_ticker                company_name  \
# 0              A  Agilent Technologies, Inc.
# 1           AAPL                  Apple Inc.
# 2           ABBV                 AbbVie Inc.
# 3           ABNB                Airbnb, Inc.
# 4            ABT         Abbott Laboratories
# 5           ACGL     Arch Capital Group Ltd.
# 6            ACN                   Accenture
# 7           ADBE                  Adobe Inc.
# 8            ADI        Analog Devices, Inc.
# 9            ADM                         ADM
#
#                                               law_id  country_match  \
# 0  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 1  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 2  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 3  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 4  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 5  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 6  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 7  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 8  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
# 9  1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉE...            0.0
#
#    sector_match  activities_match  domain_match  impact_match  \
# 0         0.050             0.017         0.000           0.0
# 1         0.000             0.000         0.017           0.0
# 2         0.000             0.000         0.000           0.0
# 3         0.056             0.018         0.017           0.0
# 4         0.000             0.000         0.000           0.0
# 5         0.000             0.000         0.018           0.0
# 6         0.000             0.018         0.017           0.0
# 7         0.000             0.018         0.017           0.0
# 8         0.000             0.000         0.017           0.0
# 9         0.056             0.018         0.017           0.0
#
#    regulator_match  score_total
# 0              0.0       0.1205
# 1              0.0       0.0169
# 2              0.0       0.0000
# 3              0.0       0.1482
# 4              0.0       0.0000
# 5              0.0       0.0175
# 6              0.0       0.0488
# 7              0.0       0.0488
# 8              0.0       0.0172
# 9              0.0       0.1485
#
# === SCORE DISTRIBUTION ===
# count    500.000000
# mean       0.042967
# std        0.059540
# min        0.000000
# 25%        0.000000
# 50%        0.015650
# 75%        0.049400
# max        0.199400
# Name: score_total, dtype: float64
#
# === TOP MATCHES BY COMPANY ===
#
# A:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.120) - Country:0.00 Sector:0.05
#
# AAPL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# ABBV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ABNB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# ABT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ACGL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.018) - Country:0.00 Sector:0.00
#
# ACN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ADBE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ADI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# ADM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# ADP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ADSK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# AEE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AEP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AES:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AFL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AIG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AIZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# AJG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AKAM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ALB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ALGN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ALL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ALLE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AMAT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# AMCR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.018) - Country:0.00 Sector:0.00
#
# AMD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# AME:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AMGN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AMP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AMT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AMZN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# ANET:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# AON:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.052) - Country:0.00 Sector:0.00
#
# AOS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# APA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# APD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# APH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# APO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# APTV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# ARE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ATO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AVB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AVGO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# AVY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# AWK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# AXON:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.034) - Country:0.00 Sector:0.00
#
# AXP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# AZO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# BA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BAC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# BALL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BAX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# BBY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.106) - Country:0.00 Sector:0.06
#
# BDX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BEN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# BIIB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# BKNG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.184) - Country:0.00 Sector:0.06
#
# BKR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BLDR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BLK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BMY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# BRO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# BSX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# BXP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# C:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# CAG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# CAH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CARR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CAT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# CBOE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CBRE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.018) - Country:0.00 Sector:0.00
#
# CCI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# CCL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# CDNS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# CDW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# CEG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CFG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# CHD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# CHRW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# CHTR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# CI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CINF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# CLX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# CMCSA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.147) - Country:0.00 Sector:0.06
#
# CME:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CMG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# CMI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CMS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CNC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CNP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# COF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# COIN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.051) - Country:0.00 Sector:0.00
#
# COO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# COP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# COR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# COST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# CPAY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CPB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# CPRT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CPT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CRL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.015) - Country:0.00 Sector:0.00
#
# CRM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# CRWD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# CSCO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# CSGP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# CSX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# CTAS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CTRA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CTSH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# CTVA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CVS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CVX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# CZR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# D:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# DAL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DASH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# DAY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# DD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DDOG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# DE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DECK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# DELL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# DG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# DGX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DHI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# DHR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.120) - Country:0.00 Sector:0.05
#
# DIS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# DLR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# DLTR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.164) - Country:0.00 Sector:0.06
#
# DOC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DOV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DOW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DPZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# DRI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# DTE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DUK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# DVA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# DVN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# DXCM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.184) - Country:0.00 Sector:0.06
#
# EBAY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.183) - Country:0.00 Sector:0.06
#
# ECL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# ED:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EFX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.034) - Country:0.00 Sector:0.00
#
# EG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EIX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# ELV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EMN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EMR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ENPH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# EOG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EPAM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.066) - Country:0.00 Sector:0.00
#
# EQIX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# EQR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EQT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ERIE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ES:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ESS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ETN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ETR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EVRG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EXC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EXE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EXPD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# EXPE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.184) - Country:0.00 Sector:0.06
#
# EXR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# F:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# FANG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# FAST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# FCX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# FDS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# FDX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# FE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# FFIV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# FI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# FICO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# FIS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# FITB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# FOX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# FOXA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# FRT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# FSLR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# FTNT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# FTV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GDDY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.084) - Country:0.00 Sector:0.00
#
# GE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GEHC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GEN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.018) - Country:0.00 Sector:0.00
#
# GEV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GILD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GIS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# GL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GLW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GNRC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GOOG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.165) - Country:0.00 Sector:0.06
#
# GOOGL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.182) - Country:0.00 Sector:0.06
#
# GPC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# GPN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.067) - Country:0.00 Sector:0.00
#
# GRMN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# GS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# GWW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# HAL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HAS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# HBAN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HCA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# HIG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HII:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HLT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# HOLX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HON:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HPE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# HPQ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# HRL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# HSIC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# HST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HSY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# HUBB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HUM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# HWM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IBM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ICE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IDXX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IEX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IFF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# INCY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# INTC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# INTU:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# INVH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IPG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IQV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# IR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IRM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# ISRG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.175) - Country:0.00 Sector:0.05
#
# ITW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# IVZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# J:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# JBHT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# JBL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.143) - Country:0.00 Sector:0.05
#
# JCI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# JKHY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# JNJ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# JPM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# K:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# KDP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# KEY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# KEYS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# KHC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.167) - Country:0.00 Sector:0.06
#
# KIM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# KKR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# KLAC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# KMB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# KMI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# KMX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.182) - Country:0.00 Sector:0.06
#
# KO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# KR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# KVUE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# L:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LDOS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# LEN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# LH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LHX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LII:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LIN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LKQ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# LLY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LMT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# LNT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.033) - Country:0.00 Sector:0.00
#
# LOW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.140) - Country:0.00 Sector:0.06
#
# LRCX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LULU:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# LUV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LVS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# LW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# LYB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# LYV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.167) - Country:0.00 Sector:0.06
#
# MA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.066) - Country:0.00 Sector:0.00
#
# MAA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MAR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# MAS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MCD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# MCHP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# MCK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# MCO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# MDLZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# MDT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MET:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# META:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.165) - Country:0.00 Sector:0.06
#
# MGM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# MHK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# MKC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.167) - Country:0.00 Sector:0.06
#
# MKTX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MLM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MMC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.034) - Country:0.00 Sector:0.00
#
# MMM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MNST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# MO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# MOH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MOS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MPC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MPWR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MRK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MRNA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MSCI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# MSFT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# MSI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# MTB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# MTCH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# MTD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# MU:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# NCLH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# NDAQ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NDSN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NEE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NEM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NFLX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.167) - Country:0.00 Sector:0.06
#
# NI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NKE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# NOC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NOW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.067) - Country:0.00 Sector:0.00
#
# NRG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NSC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.016) - Country:0.00 Sector:0.00
#
# NTAP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# NTRS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# NUE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# NVDA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# NVR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# NWS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# NWSA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# NXPI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# O:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ODFL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# OKE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# OMC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# ON:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# ORCL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# ORLY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# OTIS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# OXY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PANW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# PAYC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# PAYX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.065) - Country:0.00 Sector:0.00
#
# PCAR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PCG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PEG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PEP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# PFE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PFG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# PGR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PHM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# PKG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PLD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PLTR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# PM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# PNC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PNR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PNW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PODD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# POOL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# PPG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PPL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PRU:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.018) - Country:0.00 Sector:0.00
#
# PSA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# PSX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PTC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# PWR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# PYPL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.067) - Country:0.00 Sector:0.00
#
# QCOM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# RCL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# REG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# REGN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# RF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# RJF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# RL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# RMD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# ROK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# ROL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# ROP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ROST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# RSG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# RTX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# RVTY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SBAC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SBUX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# SCHW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SHW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SJM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.167) - Country:0.00 Sector:0.06
#
# SLB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SMCI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SNA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SNPS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# SO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SOLV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SPG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SPGI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# SRE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# STE:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# STLD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# STT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# STX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# STZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# SW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SWK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SWKS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# SYF:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SYK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# SYY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# T:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# TAP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# TDG:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TDY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TECH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.120) - Country:0.00 Sector:0.05
#
# TEL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# TER:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# TFC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TGT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# TJX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.158) - Country:0.00 Sector:0.06
#
# TKO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TMO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.138) - Country:0.00 Sector:0.05
#
# TMUS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# TPL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# TPR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# TRGP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TRMB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TROW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TRV:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TSCO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.106) - Country:0.00 Sector:0.06
#
# TSLA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TSN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.149) - Country:0.00 Sector:0.06
#
# TT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TTD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# TTWO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.199) - Country:0.00 Sector:0.06
#
# TXN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# TXT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# TYL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# UAL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# UBER:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.034) - Country:0.00 Sector:0.00
#
# UDR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# UHS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ULTA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# UNH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# UNP:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# UPS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# URI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# USB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.035) - Country:0.00 Sector:0.00
#
# V:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.048) - Country:0.00 Sector:0.00
#
# VICI:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VLO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VLTO:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VMC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VRSK:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# VRSN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# VRTX:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VTR:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VTRS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# VZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# WAB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WAT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.120) - Country:0.00 Sector:0.05
#
# WBA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.017) - Country:0.00 Sector:0.00
#
# WBD:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# WDAY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# WDC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.032) - Country:0.00 Sector:0.00
#
# WEC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WELL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WFC:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WMB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WMT:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# WRB:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WSM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.148) - Country:0.00 Sector:0.06
#
# WST:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WTW:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.036) - Country:0.00 Sector:0.00
#
# WY:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# WYNN:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.132) - Country:0.00 Sector:0.06
#
# XEL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# XOM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# XYL:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# XYZ:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# YUM:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.166) - Country:0.00 Sector:0.06
#
# ZBH:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# ZBRA:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.049) - Country:0.00 Sector:0.00
#
# ZTS:
#   1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL (0.000) - Country:0.00 Sector:0.00
#
# Results saved to: /home/sagemaker-user/shared/outputs/sec_x_laws_matches_strong.csv

# %% [markdown]
# ## Field-by-Field Analysis

# %%
# Analyze field-by-field correlations
if not matches.empty:
    print("\n=== FIELD CORRELATION ANALYSIS ===")
    
    # Show distribution of each match type
    for field in ['country_match', 'sector_match', 'activities_match', 'domain_match', 'impact_match']:
        print(f"\n{field.upper()}:")
        print(f"  Mean: {matches[field].mean():.3f}")
        print(f"  Max: {matches[field].max():.3f}")
        print(f"  Non-zero: {(matches[field] > 0).sum()}/{len(matches)}")
    
    # Show best matches per field
    print("\n=== BEST MATCHES BY FIELD ===")
    for field in ['country_match', 'sector_match', 'activities_match']:
        best = matches.nlargest(3, field)[['company_ticker', 'law_id', field, 'score_total']]
        print(f"\nTop {field}:")
        print(best.to_string(index=False))
# Out:
# === FIELD CORRELATION ANALYSIS ===
#
# COUNTRY_MATCH:
#   Mean: 0.000
#   Max: 0.000
#   Non-zero: 0/500
#
# SECTOR_MATCH:
#   Mean: 0.013
#   Max: 0.059
#   Non-zero: 115/500
#
# ACTIVITIES_MATCH:
#   Mean: 0.007
#   Max: 0.035
#   Non-zero: 180/500
#
# DOMAIN_MATCH:
#   Mean: 0.009
#   Max: 0.068
#   Non-zero: 188/500
#
# IMPACT_MATCH:
#   Mean: 0.000
#   Max: 0.000
#   Non-zero: 0/500
#
# === BEST MATCHES BY FIELD ===
#
# Top country_match:
# company_ticker                                                        law_id  country_match  score_total
#              A 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL            0.0       0.1205
#           AAPL 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL            0.0       0.0169
#           ABBV 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL            0.0       0.0000
#
# Top sector_match:
# company_ticker                                                        law_id  sector_match  score_total
#            BBY 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL         0.059       0.1059
#            LOW 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL         0.059       0.1404
#            TJX 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL         0.059       0.1576
#
# Top activities_match:
# company_ticker                                                        law_id  activities_match  score_total
#             IT 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL             0.035       0.1754
#           ABNB 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL             0.018       0.1482
#            ACN 1.DIRECTIVE (UE) 20192161 DU PARLEMENT EUROPÉEN ET DU CONSEIL             0.018       0.0488
