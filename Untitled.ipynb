# %%
# !pip install pandas

# %%
# !pip install yfinance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 33.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 158.1 MB/s eta 0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15636 sha256=7328d3abb898f193583f7d0a113155fd4f4a6e3aae76b10284c9e27d03d73e0e
#   Stored in directory: /home/sagemaker-user/.cache/pip/wheels/42/d6/84/bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# ...
#   Created wheel for peewee: filename=peewee-3.18.2-cp311-cp311-linux_x86_64.whl size=300901 sha256=df3ab29d05de0cc4e9bd932adfe9d5917c144bce44f726d7bb2ed63dcbc91d83
#   Stored in directory: /home/sagemaker-user/.cache/pip/wheels/28/84/61/758d1bd7b9c9d700158c8642a8aff2a9bf2e1ae69641c40784
# Successfully built multitasking peewee
# ...

# %%
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt


start = dt.datetime(2000,1,1)
end  = dt.datetime(2015,1,1)
tick = yf.download('AAPL', start, end)

tick
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2000-01-03   0.840094   0.844315   0.763167   0.787090  535796800
# 2000-01-04   0.769266   0.830244   0.759415   0.812419  512377600
# 2000-01-05   0.780523   0.829775   0.773018   0.778646  778321600
# 2000-01-06   0.712977   0.803038   0.712977   0.796471  767972800
# 2000-01-07   0.746750   0.758008   0.716731   0.724235  460734400
# ...               ...        ...        ...        ...        ...
# 2014-12-24  24.855762  25.011096  24.855762  24.982249   57918400
# 2014-12-26  25.295130  25.412740  24.855756  24.875726  134884000
# 2014-12-29  25.277382  25.468220  25.230780  25.250752  110395600
# 2014-12-30  24.968924  25.279593  24.877943  25.217460  119526000
# 2014-12-31  24.494043  25.104286  24.456320  25.035496  165613600
#
# [3773 rows x 5 columns]

# %%
plt.plot(tick['Close'])
